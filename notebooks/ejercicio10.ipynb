# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

from src.funciones_auxiliares import (
    duration_to_seconds,
    censurar_texto,
    reemplazar_ignore_case,
    validar_email,
    calcular_costo_envio, 
    extraer_hashtags, analizar_hashtags,
    validar_participantes, sorteo_amigo_invisible,
    cifrar_cesar, descifrar_cesar,
    limpiar_registros_alumnos,
    calcular_puntahe_ronda, obtener_ganador_ronda, procesar_competencia, generar_tabla_final
)
# Out:
# <style>.output_wrapper, .output {height:auto !important; max-height:1000px;}</style>

# %%
#Ejercicio 1: Estadística de un texto

# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

# %%
lines = text.splitlines()
total_lineas= len(lines)
print (f"Total de líneas: {total_lineas}")
# Out:
# Total de líneas: 19

# %%
palabras = text.split()
total_palabras = len(palabras)
print (f"Total de palabras: {total_palabras}")
# Out:
# Total de palabras: 137

# %%
average = total_palabras / total_lineas
print (f"Promedio de palabras por línea: {average:.2f}")
# Out:
# Promedio de palabras por línea: 7.21

# %%
print ("Lineas por encima del promedio:")
for line in lines:
    word_count= len(line.split())
    if word_count > average:
        print (f"({word_count} palabras) {line}")
# Out:
# Lineas por encima del promedio:
# (9 palabras) Special cases aren't special enough to break the rules.
# (10 palabras) In the face of ambiguity, refuse the temptation to guess.
# (13 palabras) There should be one-- and preferably only one --obvious way to do it.
# (12 palabras) Although that way may not be obvious at first unless you're Dutch.
# (8 palabras) Although never is often better than *right* now.
# (11 palabras) If the implementation is hard to explain, it's a bad idea.
# (13 palabras) If the implementation is easy to explain, it may be a good idea.
# (12 palabras) Namespaces are one honking great idea -- let's do more of those!

# %%
#Opción con Comprehension
lineas_largas = [line for line in lines if len(line.split()) > average]
for line in lineas_largas:
    print(line)
# Out:
# Special cases aren't special enough to break the rules.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
#Ejercicio 2: Duración de una playlist

# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
total_seconds=0

cancion_larga = None
cancion_corta = None
max_segundos = -1
min_segundos = float('inf')

for song in playlist:
    #itero el diccionario, y de cada canción pregunto la duración y lo paso como parámetro para la función
    segundos = duration_to_seconds (song['duration'])
    #acumulo el total de segundos que va devolviendo la función
    total_seconds+= segundos

    if segundos > max_segundos:
        #compara y busca el máximo
        max_segundos=segundos
        #guarda el diccionario de la canción
        cancion_larga= song
    if segundos < min_segundos: #hace lo mismo pero con los mínimos
        min_segundos=segundos
        cancion_corta=song

print (f"Procesamiento completado")
# Out:
# Procesamiento completado

# %%
#convertimos los segundos totales a minutos y segundos
total_minutes = total_seconds // 60
remaining_seconds= total_seconds%60

print (f"Duración total: {total_minutes}m {remaining_seconds}s")
#accedemos al diccionario guardado en la variable de máx/min
print(f"Canción más larga: \"{cancion_larga['title']}\" ({cancion_larga['duration']})")
print (f"Canción más corta: \"{cancion_corta['title']}\"({cancion_corta['duration']})")
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine"(3:07)

# %%
#Ejercicio 3: Filtro de spoilers
review = """
La película sigue a un grupo de astronautas que viajan a Marte en una misión de rescate. 
El capitán Torres lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. 
Al llegar a Marte descubren que la base está abandonada y los suministros destruidos. 
Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia.
El final revela que Torres sobrevivió gracias a un pasaje secreto.
"""

# %%
#spoilers = input ("Ingrese las palabras spoiler (separadas por coma)")

spoilers="Marte, Torres, sacrificar"
palabras_spoilers = [palabra.strip() for palabra in spoilers.split(",")]
print (f"Palabras a censurar: {palabras_spoilers}")
# Out:
# Palabras a censurar: ['Marte', 'Torres', 'sacrificar']

# %%
import re

#llamo a una función que a su vez, llama a otra función
resultado= censurar_texto(review, palabras_spoilers)
print ("\n" + "="*60)
print("TEXTO CENSURADO:")
print("="*60)
print(resultado)
# Out:
# ...
# TEXTO CENSURADO:
# ...
#
# La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate.
# El capitán ****** lidera al equipo a través de tormentas solares y fallos en el sistema de navegación.
# Al llegar a ***** descubren que la base está abandonada y los suministros destruidos.
# ****** decide ********** la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia.
# El final revela que ****** sobrevivió gracias a un pasaje secreto.

# %%
#Ejercicio 4: Validación de email

#email= input("Ingrese un email:")
email= "sandovalnair683@gmail.com"

if validar_email(email):
    print ("El email no es válido")
else:
    print ("El email es válido")
# Out:
# El email es válido

# %%
#Ejercicio 5: Calculadora de costo de envío

peso= float(input("Ingrese el peso del paquete (kg): "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ")

costo = calcular_costo_envio (peso, zona)

if costo is not None:
    print (f"Costo de envio: ${costo}")
else:
    print ('Zona no válida. Las zonas disponibles son: local, regional, nacional')

# %%
#Ejercicio 6: Análisis de hashtags

posts = [
    "Arrancando el lunes con energía #Motivación #NuevaSemana",
    "Terminé mi primer proyecto en Python #Python #Programación #OrgullosoDeMi",
    "No puedo creer el final de la serie #SinSpoilers #SerieAdicta",
    "Nuevo video en el canal sobre #InteligenciaArtificial y #Python",
    "Entrenamiento de hoy completado #Fitness #Motivación #NoPainNoGain",
    "Leyendo sobre #InteligenciaArtificial y el futuro del trabajo #Tecnología",
    "Arranqué a estudiar #Programación por mi cuenta #Python #Autodidacta",
    "Finde de lluvia, maratón de series #SerieAdicta #Relax",
    "Workshop de #InteligenciaArtificial en la universidad #Tecnología #Programación"
]

#analizar
trending, total_unicos, contador_completo = analizar_hashtags(posts)

#mostrar resultados
print ("Hashtags trending (más de una aparición): ")
#ordena (sorted)los elementos (items) de la lista trending usando como criterio el número (key=lambda x:x[1]), poniendo 1ero el que tiene nro más grande (reverse=True)
#x[0] -> sería el nombre del hashtag (la palabra)
#x[1] -> es la cantidad (el nro)
for hashtag, cantidad in sorted(trending.items(), key = lambda x: x[1], reverse= True): 
    print (f"{hashtag}: {cantidad}")

print (f"\nTotal de hashtags únicos: {total_unicos}")
# Out:
# Hashtags trending (más de una aparición):
# #Python: 3
# #Programación: 3
# #InteligenciaArtificial: 3
# #Motivación: 2
# #SerieAdicta: 2
# #Tecnología: 2
#
# Total de hashtags únicos: 13

# %%
#Séptimo ejercicio: Sorteo amigo invisible

entrada = "Ana, Pedro, Lucía, Mateo"#input("Ingrese los participantes (separados por coma): ")
nombres = entrada.split(",")

es_valido, resultado = validar_participantes(nombres)

if not es_valido:
    print (f"Error: {resultado}")
else:
    participantes = resultado
    print (f"Participantes válidos: {participantes}")

    #realizar sorteo
    sorteo= sorteo_amigo_invisible(participantes)
    print ("\nSorteo de amigo invisible: ")
    for quien, amigo in sorteo: #(por cada dupla de la lista de sorteo)
        print (f"{quien} -> {amigo}")
# Out:
# Participantes válidos: ['Ana', 'Pedro', 'Lucía', 'Mateo']
#
# Sorteo de amigo invisible:
# Ana -> Pedro
# Pedro -> Lucía
# Lucía -> Mateo
# Mateo -> Ana

# %%
#Octavo ejercicio: Cifrado César

mensaje= input("Ingrese un mensaje: ")
desplazamiento = int(input("Ingrese el desplazamiento: "))

#cifrar
cifrado= cifrar_cesar(mensaje, desplazamiento)
print(f"Mensaje cifrado: {cifrado}")

#descrifrar para verificar
descrifrado = descifrar_cesar(cifrado, desplazamiento)
print(f"Mensaje descifrado: {descrifrado}")

# %%
#ejemplo del enunciado
texto = "Hola Mundo!"
shift = 3
cifr = cifrar_cesar(texto, shift)
desc = descifrar_cesar(cifr, shift)

print(f"Original: {texto}")
print(f"Cifrado: {cifr}")      # Debe ser: Krod Pxqgr!
print(f"Descifrado: {desc}")   # Debe volver a: Hola Mundo!
# Out:
# Original: Hola Mundo!
# Cifrado: Krod Pxqgr!
# Descifrado: Hola Mundo!

# %%
#Noveno Ejercicio: Normalización de registros de alumnos
students = [
    {"name": " Ana García ", "grade": "8", "status": "aprobado"},
    {"name": "pedro lópez", "grade": "4", "status": "DESAPROBADO"},
    {"name": "MARÍA FERNÁNDEZ", "grade": "10", "status": "Aprobado"},
    {"name": "ana garcía", "grade": "9", "status": "aprobado"},
    {"name": None, "grade": "7", "status": "aprobado"},
    {"name": "Luis Martínez ", "grade": None, "status": "aprobado"},
    {"name": " carlos RUIZ", "grade": "6", "status": "aprobado"},
    {"name": "PEDRO LÓPEZ ", "grade": "3", "status": "desaprobado"},
    {"name": " ", "grade": "5", "status": "aprobado"},
    {"name": "María Fernández", "grade": "7", "status": "APROBADO"},
    {"name": "Sofía Torres", "grade": "9", "status": "Aprobado"},
    {"name": " sofía torres ", "grade": "8", "status": "aprobado"},
    {"name": "Carlos Ruiz", "grade": "6", "status": "APROBADO"},
    {"name": "Roberto Díaz", "grade": "absent", "status": "ausente"},
    {"name": "roberto díaz", "grade": "", "status": "Ausente"},
    {"name": None, "grade": None, "status": None},
    {"name": "Laura Méndez", "grade": "7", "status": "aprobado"},
    {"name": " laura méndez", "grade": "8", "status": "Aprobado"},
    {"name": "GABRIELA RÍOS", "grade": "5", "status": "aprobado"},
    {"name": "gabriela ríos ", "grade": "4", "status": "Desaprobado"},
]

#limpiar
registros_limpios = limpiar_registros_alumnos(students)

#mostrar
print("Registros limpios de alumnos")
print(f"{'Nombre':<20} {'Nota':6} {'Estado'}")
print("-"*40)

for alumno in registros_limpios:
    print(f"{alumno['name']:<20} {alumno['grade']:<6} {alumno['status']}")

print(f"\nTotal de alumnos válidos: {len(registros_limpios)}")
# Out:
# Registros limpios de alumnos
# Nombre               Nota   Estado
# ----------------------------------------
# Ana García           9      Aprobado
# Carlos Ruiz          6      Aprobado
# Gabriela Ríos        5      Aprobado
# Laura Méndez         8      Aprobado
# María Fernández      10     Aprobado
# Pedro López          4      Desaprobado
# Sofía Torres         9      Aprobado
#
# Total de alumnos válidos: 7

# %%
#Décimo ejercicio: Simulación de competencia de cocina y ranking

rounds = [
    {
        'theme': 'Entrada',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Mateo': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Camila': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Santiago': {'judge_1': 6, 'judge_2': 7, 'judge_3': 6},
            'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 8},
        }
    },
    {
        'theme': 'Plato principal',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Mateo': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Camila': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Santiago': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Lucía': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
        }
    },
    {
        'theme': 'Postre',
        'scores': {
            'Valentina': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Mateo': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Camila': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Santiago': {'judge_1': 7, 'judge_2': 7, 'judge_3': 6},
            'Lucía': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
        }
    },
    {
        'theme': 'Cocina internacional',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 9, 'judge_3': 9},
            'Mateo': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Camila': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Santiago': {'judge_1': 8, 'judge_2': 9, 'judge_3': 7},
            'Lucía': {'judge_1': 7, 'judge_2': 7, 'judge_3': 8},
        }
    },
    {
        'theme': 'Final libre',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 8, 'judge_3': 9},
            'Mateo': {'judge_1': 8, 'judge_2': 9, 'judge_3': 8},
            'Camila': {'judge_1': 7, 'judge_2': 7, 'judge_3': 7},
            'Santiago': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
            'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 7},
        }
    }
]

# %%
stats, resultados = procesar_competencia(rounds)

#mostrar resultados de cada ronda
for res in resultados:
    print (f"\n{'='*50}")
    print(f"\nRONDA {res['numero']}- {res['tema'].upper()}")
    print(f"{'='*50}")
    print(f"Ganador: {res['ganador']} ({res['puntaje_ganador']} pts)")
    print(f"\n{'Cociro':<12} {'Puntaje':<10} {'Detalle'}")
    print("-"*35)

    #ordenar por puntaje de la ronda
    #ordeno por el puntaje el 2do elemento de la tupla que me devuelve 'puntajes'
    puntaje_ordenados = sorted (res['puntajes'].items(), key=lambda x: x[1], reverse=True)
    for cook, punt in puntaje_ordenados:
        #como res[numero] empieza en 1, necesito acceder a la pos 0
        jueces = rounds[res['numero']-1]['scores'][cook]
        detalle= f"{jueces['judge_1']}+{jueces['judge_2']}+{jueces['judge_3']}"
        print(f"{cook:<12} {punt:<10} {detalle}")
# Out:
# ...
#
# RONDA 1- ENTRADA
# ...
# Ganador: Camila (26 pts)
#
# Cociro       Puntaje    Detalle
# -----------------------------------
# Camila       26         9+9+8
# Valentina    24         8+7+9
# Lucía        24         8+8+8
# Mateo        22         7+8+7
# Santiago     19         6+7+6
#
# ...
#
# RONDA 2- PLATO PRINCIPAL
# ...
# Ganador: Valentina (26 pts)
#
# Cociro       Puntaje    Detalle
# -----------------------------------
# Valentina    26         9+9+8
# Santiago     25         9+8+8
# Mateo        24         8+7+9
# Lucía        22         7+8+7
# Camila       20         7+6+7
#
# ...
#
# RONDA 3- POSTRE
# ...
# Ganador: Lucía (27 pts)
#
# Cociro       Puntaje    Detalle
# -----------------------------------
# Lucía        27         9+9+9
# Mateo        26         9+9+8
# Camila       24         8+7+9
# Valentina    22         7+8+7
# Santiago     20         7+7+6
#
# ...
#
# RONDA 4- COCINA INTERNACIONAL
# ...
# Ganador: Valentina (26 pts)
#
# Cociro       Puntaje    Detalle
# -----------------------------------
# ...

# %%
tabla_final = generar_tabla_final(stats)

print(f"\n{'='*60}")
print("TABLA DE POSICIONES FINAL")
print (f"{'='*60}")
print(f"{'Cocinero':<12} {'Total':<8} {'Ganadas':<10} {'Mejor':<8} {'Promedio':<10}")
print('-'*60)

for fila in tabla_final:
    print(f"{fila['cocinero']:<12} {fila['total']:<8} {fila['rondas_ganadas']:<10}" f"{fila['mejor_ronda']:<8} {fila['promedio']:10.1f}")

print('-'*60)
# Out:
# ...
# TABLA DE POSICIONES FINAL
# ...
# Cocinero     Total    Ganadas    Mejor    Promedio
# ------------------------------------------------------------
# Valentina    124      2         26             24.8
# Lucía        118      1         27             23.6
# Mateo        117      0         26             23.4
# Camila       116      1         26             23.2
# Santiago     115      1         27             23.0
# ------------------------------------------------------------
